# %% [markdown]
# 1. System message - Tell the mofel how to behave and provide context for interactions.
# 2. human message - Represents user input and interactions with the model
# 3. AI message - Represents Generated by the model including text content, tool calls , and metadata
# 4. Tools message - Represents the out put of the tool calls

# %% [markdown]
# 0. Role - Identify the message type
# 0. Content - Represents the actual content of the message (linke text, image, audio docments, etc.)
# 0. metadata - Operational fields such as response information, message IDs and token usage
